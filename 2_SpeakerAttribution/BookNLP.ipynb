# %% [markdown]
# # Downloading Libraries

# %%
# !pip install booknlp
# !python -m spacy download en_core_web_sm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 65.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 36.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.30.2

# %%
# pip install transformers==4.30.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 64.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 62.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# ...

# %%
from booknlp.booknlp import BookNLP
import json
from collections import Counter
from pathlib import Path
import pandas as pd
# Out:
# using device cuda

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 20.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# ...

# %% [markdown]
# # Load Dataset

# %%
from datasets import load_dataset
import pandas as pd

# Load the dataset
ds = load_dataset("honicky/short_childrens_stories_with_labeled_character_names")

# Convert the training set to a DataFrame
df_train = pd.DataFrame(ds['train'])
df_train.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/815 [00:00<?, ?B/s]
# stories_and_character_names.parquet:   0%|          | 0.00/3.07M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2588 [00:00<?, ? examples/s]
#                                                story  \
# 0   In a small town named Mathville, lived two be...
# 1   One sunny day, Alex and Jamie decided to go f...
# 2   In the hot, dusty town of Mississippi during ...
# ...

# %% [markdown]
# # Initialize BookNLP

# %%
model_params = {
		"pipeline":"entity,quote,supersense,event,coref",
		"model":"big",
	}

booknlp= BookNLP("en", model_params)
# Out:
# {'pipeline': 'entity,quote,supersense,event,coref', 'model': 'big'}
# downloading entities_google_bert_uncased_L-6_H-768_A-12-v1.0.model
# downloading coref_google_bert_uncased_L-12_H-768_A-12-v1.0.model
# downloading speaker_google_bert_uncased_L-12_H-768_A-12-v1.0.1.model
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/270M [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# --- startup: 86.662 seconds ---

# %%
import pandas as pd
import random
from booknlp.booknlp import BookNLP

# 1. Randomly select N indices
n = 10
random_indices = random.sample(list(df_train.index), n)

# Save indices
selected_indices = random_indices

# 3. Process each selected story
for idx in selected_indices:
    story_text = df_train.loc[idx, 'story']

    # Optional: Create temp input/output paths if needed
    with open("input.txt", "w", encoding="utf-8") as f:
        f.write(story_text)

    # Output directory for BookNLP results
    booknlp_output_directory = "booknlp_output"

    # Run BookNLP
    booknlp.process( "input.txt", booknlp_output_directory, f"story_{idx}"
    )
# Out:
# --- spacy: 0.080 seconds ---
# --- entities: 1.272 seconds ---
# --- quotes: 0.000 seconds ---
# --- attribution: 0.154 seconds ---
# --- name coref: 0.000 seconds ---
# --- coref: 3.666 seconds ---
# --- TOTAL (excl. startup): 5.176 seconds ---, 331 words
# --- spacy: 0.089 seconds ---
# --- entities: 0.778 seconds ---
# --- quotes: 0.000 seconds ---
# --- attribution: 0.059 seconds ---
# --- name coref: 0.000 seconds ---
# --- coref: 2.684 seconds ---
# --- TOTAL (excl. startup): 3.612 seconds ---, 318 words
# --- spacy: 0.044 seconds ---
# --- entities: 0.474 seconds ---
# --- quotes: 0.000 seconds ---
# --- attribution: 0.067 seconds ---
# --- name coref: 0.000 seconds ---
# --- coref: 2.518 seconds ---
# --- TOTAL (excl. startup): 3.105 seconds ---, 262 words
# --- spacy: 0.064 seconds ---
# --- entities: 0.717 seconds ---
# --- quotes: 0.000 seconds ---
# --- attribution: 0.075 seconds ---
# --- name coref: 0.000 seconds ---
# --- coref: 2.646 seconds ---
# ...

# %%
df_train["story"][13]
# Out:
# ' Long, long ago in a small village nestled between two tall mountains lived a group of curious animals who loved learning new things every day. They had heard stories about a magical rainbow that appeared after a heavy storm, but none of them had ever seen one before. So they decided to embark on an adventure to find out how rainbows were made!\n\nAs their journey began, Bunny asked Chipmunk, "I know what makes rain, but I don\'t understand how those drops create colors!" Clever Owl overhead their question and replied, "Well my friends, when sunlight shines through droplets of water, something called \'refraction\' happens." He continued, "Refraction is when light changes direction because it enters a medium with different properties, like air or water. This causes the separation of white light into its individual colors!"\n\nExcitedly, Squirrel exclaimed, "So we need both sunshine and raindrops to see a rainbow? That sounds right!" As they climbed higher up the mountain, suddenly t
# ...

# %%
df_quotes = pd.read_csv("/content/booknlp_output/story_13.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0           77         95             73           73          Bunny        0
# 1          104        124            125          125             He       10
# 2          128        161            125          125             He       10
# 3          167        184            164          164       Squirrel        3
# 4          242        245            247          247         Rabbit        4
# 5          260        306            254          256   Wise Old Owl        5
#
#                                                quote
# 0   I know what makes rain , but I do n't underst...
# 1   Well my friends , when sunlight shines throug...
# 2   Refraction is when light changes direction be...
# 3   So we need both sunshine and raindrops to see...
# 4                                            Wait ,
# 5   Children , remember our science discussion ea...

# %%
character_data_coref = json.load(open("/content/booknlp_output/story_13.book"))

# %%
def get_counter_from_dependency_list(dependency_list):

    counter = Counter()

    for token in dependency_list:
        term = token["w"]
        tokenGlobalIndex=token["i"]
        counter[term] += 1
    return counter

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#     Name Character ID  Mentions   Gender Possessives  \
# 0  Bunny            0         3  she/her          []
#
#                                       Agent Patient Modifiers
# 0  [(understand, 2), (asked, 1), (know, 1)]      []        []

# %%
df_train["story"][1550]
# Out:
# ' In a small town named Chillyville, way up north in Alaska, lived two curious little seeds named Almond and Aloi. They dreamed of becoming big and strong like the trees and flowers they had heard about in their seed stories. One sunny day, they decided to set out on an adventure to find their perfect home to grow.\n\nAs they rolled along, Almond asked, "Have you ever wondered what kind of place would be best for us?" Aloi replied thoughtfully, "Well, I know we need warmth and water, so let\'s explore and see what we can find!"\n\nThey came across many beautiful places—shiny snowy mountains, deep blue lakes, and dense forests. But something didn\'t feel right; neither Almond nor Aloi felt themselves growing or thriving. Eventually, they met Wise Old Squirrel who noticed how tired and sad they looked. He asked if he could help.\n\nAlmond shared their dreams and struggles. Kindly, Wise Old Squirrel explained, "Dear friends, your stories told of different lands—Mediterranean for Almond 
# ...

# %%
df_quotes = pd.read_csv("/content/booknlp_output/story_1550.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end     mention_phrase  \
# 0           72         87             69           69             Almond
# 1           92        114             69           69             Almond
# 2          188        222            183          185  Wise Old Squirrel
#
#    char_id                                              quote
# 0        2   Have you ever wondered what kind of place wou...
# 1        2   Well , I know we need warmth and water , so l...
# 2        4   Dear friends , your stories told of different...

# %%
character_data_coref = json.load(open("/content/booknlp_output/story_1550.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#                 Name Character ID  Mentions           Gender Possessives  \
# 0             Almond            2         7  they/them/their          []
# 1               Aloi            3         6  they/them/their          []
# 2  Wise Old Squirrel            4         4       he/him/his          []
#
#                                              Agent     Patient Modifiers
# 0  [(asked, 1), (know, 1), (felt, 1), (shared, 1)]          []        []
# 1         [(wondered, 1), (replied, 1), (felt, 1)]          []        []
# 2          [(asked, 1), (help, 1), (explained, 1)]  [(met, 1)]        []

# %%
df_train["story"][1934]
# Out:
# ' In a bustling digital world, there lived two best friends, Techno Timmy and Wonder Wihelmina. They were always eager to learn new things, especially when it came to technology and science! One sunny day, while chatting online, Timmy excitedly typed:\n\nTimmy: "*@wonderwihelmina* WAIT TILL YOU SEE WHAT I MADE!! IT\'S SO COOL!"\n\nIntrigued by her friend\'s enthusiasm, Wihelmina asked, "What is it, Timmy?" She couldn\'t wait to find out! With pride gleaming in his eyes, Timmy replied:\n\nTimmy: "It\'s a superfast gadget... something I built myself! And guess what? *Its a gift!* Just for you."\n\nWihelmina was overjoyed and amazed at how fast the gadget worked. But then she noticed something strange happening – every time she used it, flowers around town began wilting! Surprised, she shared her observations with Timmy. He was puzzled too and decided to investigate with her.\n\nTogether, they explored the ins and outs of the mysterious device until finally, they discovered the problem:
# ...

# %%
df_quotes = pd.read_csv("/content/booknlp_output/story_1934.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0           50         68             48           48          Timmy        0
# 1           79         86             76           76      Wihelmina        1
# 2          107        133            105          105          Timmy        0
#
#                                                quote
# 0   * @wonderwihelmina * WAIT TILL YOU SEE WHAT I...
# 1                              What is it , Timmy ?
# 2   It 's a superfast gadget ... something I buil...

# %%
character_data_coref = json.load(open("/content/booknlp_output/story_1934.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#         Name Character ID  Mentions      Gender  \
# 0      Timmy            0        12  he/him/his
# 1  Wihelmina            1        12     she/her
#
#                         Possessives  \
# 0                       [(eyes, 1)]
# 1  [(friend, 1), (observations, 1)]
#
#                                                Agent  \
# 0  [(typed, 1), (MADE, 1), (replied, 1), (built, 1)]
# 1  [(SEE, 1), (asked, 1), (wait, 1), (noticed, 1)...
#
#                                   Patient Modifiers
# 0  [(typed, 1), (built, 1), (puzzled, 1)]        []
# 1                                      []        []

# %%
df_train["story"][2029]
# Out:
# ' In a bustling forest filled with vibrant colors, two best friends - Benny the Beaver and Sammy the Squirrel - were curious about why some trees had smooth bark while others had rough texture. They embarked on an adventure to find answers.\n\nAs they journeyed deeper into the woods, Benny asked, "Sammy, do you know why some tree trunks feel so different than others?" With his tiny hands still clutching acorns, Sammy replied, "No idea, Benny! But let\'s climb up these tall trees and see if we can spot any clues!"\n\nReaching the treetops together, they marveled at how high they had climbed. From their new vantage point, they saw patches of light green needles on some trees and broad flat leaves on others. Then, Benny noticed something interesting, "Look over there, Sammy! Those needle-covered trees seem to have smoother bark compared to our leafy ones!"\n\nExcitedly, he remembered what Mrs. Oakley Owl taught him during last winter\'s gathering – evergreens keep their needle-like leav
# ...

# %%
df_quotes = pd.read_csv("/content/booknlp_output/story_2029.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0           56         72             53           53          Benny        2
# 1           84        107             81           81          Sammy        1
# 2          152        175            147          147          Benny        2
# 3          245        262            264          264          Sammy        1
#
#                                                quote
# 0   Sammy , do you know why some tree trunks feel...
# 1   No idea , Benny ! But let 's climb up these t...
# 2   Look over there , Sammy ! Those needle - cove...
# 3   So , it seems that those warm - weather lovin...

# %%
character_data_coref = json.load(open("/content/booknlp_output/story_2029.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#     Name Character ID  Mentions      Gender   Possessives  \
# 0  Sammy            1         7  he/him/his  [(hands, 1)]
# 1  Benny            2         6  he/him/his            []
#
#                                          Agent        Patient Modifiers
# 0         [(know, 1), (replied, 1), (said, 1)]   [(Benny, 1)]        []
# 1  [(asked, 1), (noticed, 1), (remembered, 1)]  [(taught, 1)]        []

# %%
df_train["story"][0]
# Out:
# ' In a small town named Mathville, lived two best friends, Algy and Sammy. They loved solving puzzles and riddles together. One sunny day, they found a mysterious note on their favorite park bench. It read, “Solve -1147 = -11*a - 1213 for ‘a’. What is the answer?”\n\nAlgy, being good at numbers, decided to take up the challenge. He explained to Sammy, “First, we need to get ‘a’ alone. To do that, let’s add 1213 to both sides of the equation.” So, they added 1213 to -1147, making it 66.\n\nNext, Algy said, “Now, we simplify both sides to make our work easier!” And voila! Both sides became 66. Excitedly, he shared his next step with Sammy: “Let’s divide both sides by -11 now, so we can finally see what ‘a’ equals!" A little confused, Sammy asked, “But won’t negative divided by negative give us positive? Why would we want to use minus here?"\n\nWith a smile, Algy replied, “Great question, Sammy! Yes, usually, negative divided by negative gives us positive. But when you divide a number b
# ...

# %%
df_quotes = pd.read_csv("/content/booknlp_output/story_0.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0           42         59             74           74             He        4
# 1           79        106             74           74             He        4
# 2          124        137            121          121           Algy        0
# 3          156        177            148          148             he        4
# 4          185        206            182          182          Sammy        1
# 5          214        282            211          211           Algy        0
#
#                                                quote
# 0  “ Solve -1147 = -11*a - 1213 for ‘ a ’ . What ...
# 1  “ First , we need to get ‘ a ’ alone . To do t...
# 2  “ Now , we simplify both sides to make our wor...
# 3  “ Let ’s divide both sides by -11 now , so we ...
# 4  “ But wo n’t negative divided by negative give...
# 5  “ Great question , Sammy ! Yes , usually , neg...

# %%
character_data_coref = json.load(open("/content/booknlp_output/story_0.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#     Name Character ID  Mentions           Gender Possessives  \
# 0  Sammy            1         5       he/him/his          []
# 1   Algy            0         4  they/them/their          []
#
#                        Agent Patient    Modifiers
# 0               [(asked, 1)]      []           []
# 1  [(said, 1), (replied, 1)]      []  [(good, 1)]

# %%
df_train["story"][2488]
# Out:
# ' Once there was a little Eclectus Parrot named Eddie. Eddie lived in a small cage, much smaller than what his friend Polly the Macaw had. One day, while talking on the phone, Polly asked Eddie why he lived in such a tiny home.\n\n"My human says I don\'t need a big cage," Eddie replied. "She thinks I\'m happy here."\n\nPolly suggested they talk to Dr. Finch, their local bird expert, who would help Eddie understand the importance of having a spacious habitat. At Dr. Finch\'s office, they discovered fascinating facts about birds needing room to fly, hop, climb, and explore to stay healthy and content. She explained how bigger spaces allowed for toys, perches, and various activities that kept Eddie mentally stimulated.\n\nDr. Finch said, "Imagine being cooped up all day without any change in scenery! Birds require enriching environments to live happily."\n\nEddie finally realized how vital space was for him. He returned home and shared his newfound knowledge with his human companion. To
# ...

# %%
df_quotes = pd.read_csv("/content/booknlp_output/story_2488.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0           49         61             62           62          Eddie        0
# 1           65         73             62           62          Eddie        0
# 2          153        174            149          150      Dr. Finch        2
#
#                                                quote
# 0          My human says I do n't need a big cage ,
# 1                      She thinks I 'm happy here .
# 2   Imagine being cooped up all day without any c...

# %%
character_data_coref = json.load(open("/content/booknlp_output/story_2488.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#         Name Character ID  Mentions           Gender  \
# 0      Eddie            0        27       he/him/his
# 1      Polly            1         5          she/her
# 2  Dr. Finch            2         3  they/them/their
#
#                                          Possessives  \
# 0  [(human, 2), (friend, 1), (knowledge, 1), (com...
# 1                                                 []
# 2                                      [(office, 1)]
#
#                                                Agent                  Patient  \
# 0  [(lived, 2), (need, 1), (replied, 1), (underst...  [(asked, 1), (kept, 1)]
# 1  [(asked, 1), (suggested, 1), (explained, 1), (...                       []
# 2                                        [(said, 1)]                       []
#
#       Modifiers
# 0  [(happy, 1)]
# 1            []
# 2            []

# %%
df_train["story"][15]
# Out:
# " In the heart of a lush green forest, there lived many happy animals who called it home. There were fluffy bunnies hopping around, busy squirrels collecting nuts, and tall deer grazing on juicy leaves. High up above, colorful birds sang beautiful songs all day long. At the center of the forest was a wise old owl named Oliver, who loved observing his friends and fellow creatures.\n\nOne sunny morning, while chatting with Chippy the chipmunk, Oliver noticed something unusual. The air felt different – it was thicker and harder to breathe. They both wondered what had changed. That's when Fiona Fox appeared, coughing and sneezing uncontrollably. She shared her concern, “I smelled smoke earlier today! Do you think there might be a fire nearby?”\n\nWith worried expressions, they decided to investigate further. As they explored deeper into the woods, wisps of smoky clouds began appearing more frequently. Suddenly, they saw flames flickering menacingly close by. It became evident; a terrible
# ...

# %%
df_train["characters"][15]
# Out:
# 'Oliver,Chippy the chipmunk,Fiona Fox'

# %%
df_quotes = pd.read_csv("/content/booknlp_output/story_15.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0          128        145            123          123            She        2
# 1          295        317            292          292             He        0
#
#                                                quote
# 0  “ I smelled smoke earlier today ! Do you think...
# 1  “ We must spread awareness about protecting fo...

# %%
character_data_coref = json.load(open("/content/booknlp_output/story_15.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#         Name Character ID  Mentions      Gender  \
# 0     Oliver            0         6  he/him/his
# 1  Fiona Fox            2         4     she/her
#
#                       Possessives  \
# 0  [(friends, 1), (creatures, 1)]
# 1                  [(concern, 1)]
#
#                                                Agent Patient Modifiers
# 0  [(noticed, 1), (think, 1), (remembered, 1), (s...      []        []
# 1         [(appeared, 1), (shared, 1), (smelled, 1)]      []        []

# %%
df_train["story"][19]
# Out:
# ' In the heart of a bustling city, lived a curious boy named Timmy and his teddy bear, Einstein. One sunny day, they decided to visit the aviation museum. As they admired the big, powerful machines, Timmy noticed something unusual – a twisted metal heap in the corner. It looked like a bird with broken wings, missing its tail feathers.\n\n"Einstein," asked Timmy, holding his teddy tightly, "what happened here?"\n\nEinstein replied, "Well Timmy, sometimes when birds fly too close to the sun or work too hard without rest, their engines overheat, causing trouble."\n\nTimmy gasped, "Like a fever? But planes aren\'t alive!"\n\nWith a wise nod, Einstein explained, "True, but airplanes do need fuel and care, much like our bodies require food and sleep. This wreckage tells us that maybe someone forgot to give it enough rest or proper maintenance."\n\nAs they continued exploring, Timmy saw various aircraft types - single engine propellers, jets, even a strange-looking helicopter with two spinn
# ...

# %%
df_quotes = pd.read_csv("/content/booknlp_output/story_19.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0           69         72             74           74          Timmy        0
# 1           81         86             74           74          Timmy        0
# 2           90        117             87           87       Einstein        1
# 3          121        132            118          118          Timmy        0
# 4          141        178            138          138       Einstein        1
# 5          234        258            285          285         Helena        2
# 6          264        284            261          261          Timmy        0
# 7          289        336            285          285         Helena        2
#
#                                                quote
# 0                                        Einstein ,
# 1                              what happened here ?
# 2   Well Timmy , sometimes when birds fly too clo...
# 3         Like a fever ? But planes are n't alive !
# ...

# %%
character_data_coref = json.load(open("/content/booknlp_output/story_19.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#        Name Character ID  Mentions      Gender  \
# 0     Timmy            0        14  he/him/his
# 1    Helena            2        12     she/her
# 2  Einstein            1         4  he/him/his
#
#                                          Possessives  \
# 0                            [(bear, 1), (teddy, 1)]
# 1  [(sister, 2), (name, 1), (friend, 1), (pressur...
# 2                                                 []
#
#                                                Agent  \
# 0  [(noticed, 1), (gasped, 1), (saw, 1), (approac...
# 1  [(talk, 1), (sighed, 1), (suffered, 1), (seize...
# 2         [(asked, 1), (replied, 1), (explained, 1)]
#
#                        Patient       Modifiers
# 0  [(asked, 1), (promised, 1)]              []
# 1                           []  [(chopper, 1)]
# 2                           []              []

# %%
df_train["story"][1965]
# Out:
# ' In Atomville, every creature was made up of tiny particles called atoms. Our friend Electra was an elephant who lived there, and she loved learning about how her own body worked! One day, she asked her best friend Proton, a curious rabbit, “Proton, I know my electrons carry a negative charge and move around in different levels. But why do they have more energy when they’re far from my core?”\n\nProton replied, “Well, Electra, imagine your house has several floors, and each floor needs some power to keep working. Your ground floor might only need enough electricity for a few lights, while the topmost floor may require much more power for all the gadgets inside. That extra power needed on higher floors can be compared to the increased energy in outer electron levels!”\n\nElectra nodded, understanding better now. She had always thought of herself as big, strong, and full of energy. However, hearing Proton compare her to a building helped her realize that being bigger didn’t necessaril
# ...

# %%
df_quotes = pd.read_csv("/content/booknlp_output/story_1965.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0           49         82             38           38            she        1
# 1           86        155             83           83         Proton        2
# 2          229        259            226          226             He       11
# 3          313        336            304          304        Neutron        3
#
#                                                quote
# 0  “ Proton , I know my electrons carry a negativ...
# 1  “ Well , Electra , imagine your house has seve...
# 2  “ But remember , even though these outer elect...
# 3  “ Even though we lost some energy , let ’s wor...

# %%
character_data_coref = json.load(open("/content/booknlp_output/story_1965.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#       Name Character ID  Mentions           Gender  \
# 0  Electra            1        19          she/her
# 1   Proton            2         4          she/her
# 2  Neutron            3         2  they/them/their
#
#                                          Possessives  \
# 0  [(electrons, 2), (body, 1), (friend, 1), (core...
# 1                                                 []
# 2                                      [(advice, 1)]
#
#                                                Agent         Patient Modifiers
# 0  [(loved, 1), (asked, 1), (know, 1), (imagine, ...  [(compare, 1)]        []
# 1                       [(replied, 1), (compare, 1)]              []        []
# 2                                                 []              []        []

# %%
df_train["story"][2489]
# Out:
# ' Little Aubrey loved to gaze up at the bright blue sky every day. She often wondered why the sky looked so beautiful and colorful during sunrise and sunset. One day, while talking to her friend Billy who studied animals and nature, she learned about how Earth\'s atmosphere scatters sunlight, making the sky appear blue. This made Aubrey appreciate the beauty around her even more!\n\nOne fateful afternoon, however, Aubrey discovered something shocking - her fiancé Carson had been cheating on her. Hurt and angry, she asked him to return her engagement ring. They sat down under their favorite tree, and Aubrey said, "Carson, I cannot trust you anymore. It breaks my heart, but we must part ways."\n\nFeeling confused and lost, Aubrey reached out to her trusted biology teacher Mrs. Luna for advice. Mrs. Luna listened carefully and then explained how plants grow stronger when they face strong winds and harsh conditions. In life, sometimes facing adversities helps us become wiser and prepares
# ...

# %%
df_quotes = pd.read_csv("/content/booknlp_output/story_2489.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0          117        138            114          114         Aubrey        1
#
#                                                quote
# 0   Carson , I can not trust you anymore . It bre...

# %%
character_data_coref = json.load(open("/content/booknlp_output/story_2489.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#         Name Character ID  Mentions      Gender  \
# 0     Aubrey            1        33     she/her
# 1     Carson            3         5  he/him/his
# 2  Mrs. Luna            4         4     she/her
#
#                                          Possessives  \
# 0  [(friend, 1), (fiancé, 1), (ring, 1), (heart, ...
# 1                                                 []
# 2                                      [(wisdom, 1)]
#
#                                                Agent  \
# 0  [(loved, 2), (discovered, 2), (wondered, 1), (...
# 1                                    [(cheating, 1)]
# 2                    [(listened, 1), (explained, 1)]
#
#                      Patient Modifiers
# 0  [(lifting, 1), (heal, 1)]        []
# 1   [(asked, 1), (trust, 1)]        []
# 2             [(thanked, 1)]        []

# %%
selected_indices
# Out:
# [13, 1550, 1934, 2029, 0, 2488, 15, 19, 1965, 2489]

# %% [markdown]
# # BookNLP + FastCoref

# %%
pip install fastcoref
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fastcoref: filename=fastcoref-2.1.6-py3-none-any.whl size=31254 sha256=8ef2a6badd1837954d1bbb457a5ebf22bf1c4335f17b484265e3c5f756876116
#   Stored in directory: /root/.cache/pip/wheels/21/76/e3/e6a46e5f2c8eb3e3e91b5615b29886c799bb702e7fe9f57274
# Successfully built fastcoref
# ...

# %%
import re
import spacy
from fastcoref import spacy_component

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("fastcoref")  # Add coreference resolution component

def mask_double_quotes(text):
    """Replaces all types of double-quoted text (straight or curly) with placeholders."""
    # Matches text inside either "..." or “...”, non-greedy, across lines too
    quote_pattern = r'(?:(?:"|“)(.*?)(?:"|”))'
    placeholders = {}

    def replacer(match):
        full_quote = match.group(0)
        placeholder = f"__QUOTE_{len(placeholders)}__"
        placeholders[placeholder] = full_quote
        return placeholder

    masked_text = re.sub(quote_pattern, replacer, text, flags=re.DOTALL)
    return masked_text, placeholders

def unmask_double_quotes(text, placeholders):
    """Restores the original text inside double quotes."""
    for placeholder, original in placeholders.items():
        text = text.replace(placeholder, original)
    return text

def resolve_coreferences(text):
    # Step 1: Mask double-quoted text
    masked_text, placeholders = mask_double_quotes(text)

    # Step 2: Perform coreference resolution
    doc = nlp(masked_text, component_cfg={"fastcoref": {'resolve_text': True}})

    # Step 3: Get resolved text
    resolved_text = doc._.resolved_text

    # Step 4: Restore double-quoted text
    final_text = unmask_double_quotes(resolved_text, placeholders)

    return final_text
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:896: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/819 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/393 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/362M [00:00<?, ?B/s]

# %%
# Loop through each selected index
for idx in selected_indices:
    # 1. Grab the story
    story_text = df_train.loc[idx, 'story']

    # 2. Resolve coreferences (one at a time)
    resolved_text = resolve_coreferences(story_text)

    # 3. Save to temporary file (required by BookNLP)
    input_path = f"temp_input_{idx}.txt"
    output_dir = f"booknlp_output_FastCoref/story_{idx}"

    with open(input_path, "w", encoding="utf-8") as f:
        f.write(resolved_text)

    # 4. Run BookNLP on this file
    booknlp.process(
        input_path,
        output_dir,
        f"story_{idx}"
    )
# Out:
# ...
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# --- spacy: 0.137 seconds ---
# --- entities: 0.937 seconds ---
# --- quotes: 0.001 seconds ---
# --- attribution: 0.126 seconds ---
# --- name coref: 0.000 seconds ---
# --- coref: 5.120 seconds ---
# --- TOTAL (excl. startup): 6.325 seconds ---, 425 words
# ...
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# --- spacy: 0.122 seconds ---
# --- entities: 2.554 seconds ---
# --- quotes: 0.001 seconds ---
# --- attribution: 0.161 seconds ---
# --- name coref: 0.001 seconds ---
# --- coref: 8.452 seconds ---
# --- TOTAL (excl. startup): 11.296 seconds ---, 462 words
# ...
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# --- spacy: 0.057 seconds ---
# --- entities: 1.279 seconds ---
# --- quotes: 0.000 seconds ---
# --- attribution: 0.171 seconds ---
# --- name coref: 0.001 seconds ---
# --- coref: 6.167 seconds ---
# --- TOTAL (excl. startup): 7.679 seconds ---, 289 words
# ...
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
df_train["story"][13]
# Out:
# ' Long, long ago in a small village nestled between two tall mountains lived a group of curious animals who loved learning new things every day. They had heard stories about a magical rainbow that appeared after a heavy storm, but none of them had ever seen one before. So they decided to embark on an adventure to find out how rainbows were made!\n\nAs their journey began, Bunny asked Chipmunk, "I know what makes rain, but I don\'t understand how those drops create colors!" Clever Owl overhead their question and replied, "Well my friends, when sunlight shines through droplets of water, something called \'refraction\' happens." He continued, "Refraction is when light changes direction because it enters a medium with different properties, like air or water. This causes the separation of white light into its individual colors!"\n\nExcitedly, Squirrel exclaimed, "So we need both sunshine and raindrops to see a rainbow? That sounds right!" As they climbed higher up the mountain, suddenly t
# ...

# %%
df_train["characters"][13]
# Out:
# 'Bunny,Chipmunk,Owl,Squirrel,Rabbit'

# %%
df_quotes = pd.read_csv("/content/booknlp_output_FastCoref/story_13/story_13.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0          122        140            118          118          Bunny        0
# 1          161        181            141          142     Clever Owl        2
# 2          186        219            182          183     Clever Owl        2
# 3          225        242            222          222       Squirrel        3
# 4          323        326            328          328         Rabbit        4
# 5          341        387            335          337   Wise Old Owl        5
#
#                                                quote
# 0   I know what makes rain , but I do n't underst...
# 1   Well my friends , when sunlight shines throug...
# 2   Refraction is when light changes direction be...
# 3   So we need both sunshine and raindrops to see...
# 4                                            Wait ,
# 5   Children , remember our science discussion ea...

# %%
character_data_coref = json.load(open("/content/booknlp_output_FastCoref/story_13/story_13.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#          Name Character ID  Mentions      Gender     Possessives  \
# 0       Bunny            0         3     she/her              []
# 1  Clever Owl            2         3  he/him/his  [(friends, 1)]
#
#                                       Agent Patient Modifiers
# 0  [(understand, 2), (asked, 1), (know, 1)]      []        []
# 1                          [(continued, 1)]      []        []

# %%
df_train["story"][1550]
# Out:
# ' In a small town named Chillyville, way up north in Alaska, lived two curious little seeds named Almond and Aloi. They dreamed of becoming big and strong like the trees and flowers they had heard about in their seed stories. One sunny day, they decided to set out on an adventure to find their perfect home to grow.\n\nAs they rolled along, Almond asked, "Have you ever wondered what kind of place would be best for us?" Aloi replied thoughtfully, "Well, I know we need warmth and water, so let\'s explore and see what we can find!"\n\nThey came across many beautiful places—shiny snowy mountains, deep blue lakes, and dense forests. But something didn\'t feel right; neither Almond nor Aloi felt themselves growing or thriving. Eventually, they met Wise Old Squirrel who noticed how tired and sad they looked. He asked if he could help.\n\nAlmond shared their dreams and struggles. Kindly, Wise Old Squirrel explained, "Dear friends, your stories told of different lands—Mediterranean for Almond 
# ...

# %%
df_train["characters"][1550]
# Out:
# 'Almond,Aloi,Wise Old Squirrel'

# %%
df_quotes = pd.read_csv("/content/booknlp_output_FastCoref/story_1550/story_1550.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end  \
# 0          116        131            132          132
# 1          136        158            132          132
# 2          296        330            281          285
#
#                mention_phrase  char_id  \
# 0                        Aloi        5
# 1                        Aloi        5
# 2  Kindly , Wise Old Squirrel        6
#
#                                                quote
# 0   Have you ever wondered what kind of place wou...
# 1   Well , I know we need warmth and water , so l...
# 2   Dear friends , your stories told of different...

# %%
character_data_coref = json.load(open("/content/booknlp_output_FastCoref/story_1550/story_1550.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#                 Name Character ID  Mentions           Gender  \
# 0               Aloi            5        23  they/them/their
# 1             Almond            4        21  they/them/their
# 2  Wise Old Squirrel            6         4  they/them/their
#
#                                          Possessives  \
# 0  [(stories, 1), (home, 1), (dreams, 1), (strugg...
# 1                                                 []
# 2                                                 []
#
#                                                Agent                 Patient  \
# 0  [(wondered, 1), (replied, 1), (know, 1), (felt...                      []
# 1               [(asked, 1), (felt, 1), (shared, 1)]                      []
# 2                                        [(help, 1)]  [(met, 1), (asked, 1)]
#
#   Modifiers
# 0        []
# 1        []
# 2        []

# %%
df_quotes = pd.read_csv("/content/booknlp_output_FastCoref/story_1934/story_1934.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end    mention_phrase  \
# 0           60         78             57           58      Techno Timmy
# 1           92         99             88           89  Wonder Wihelmina
# 2          125        151            122          123      Techno Timmy
#
#    char_id                                              quote
# 0        0   * @wonderwihelmina * WAIT TILL YOU SEE WHAT I...
# 1        1                              What is it , Timmy ?
# 2        0   It 's a superfast gadget ... something I buil...

# %%
character_data_coref = json.load(open("/content/booknlp_output_FastCoref/story_1934/story_1934.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#                Name Character ID  Mentions           Gender  \
# 0      Techno Timmy            0        15       he/him/his
# 1  Wonder Wihelmina            1        12  they/them/their
#
#                         Possessives  \
# 0            [(eyes, 1), (gift, 1)]
# 1  [(friend, 1), (observations, 1)]
#
#                                                Agent  \
# 0  [(typed, 1), (MADE, 1), (replied, 1), (built, 1)]
# 1  [(SEE, 1), (asked, 1), (wait, 1), (noticed, 1)...
#
#                                   Patient Modifiers
# 0  [(typed, 1), (built, 1), (puzzled, 1)]        []
# 1                                      []        []

# %%
df_quotes = pd.read_csv("/content/booknlp_output_FastCoref/story_2029/story_2029.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end      mention_phrase  \
# 0           78         94             73           75    Benny the Beaver
# 1          111        134            106          108  Sammy the Squirrel
# 2          222        245            215          217    Benny the Beaver
# 3          318        335            337          339  Sammy the Squirrel
#
#    char_id                                              quote
# 0        0   Sammy , do you know why some tree trunks feel...
# 1        1   No idea , Benny ! But let 's climb up these t...
# 2        0   Look over there , Sammy ! Those needle - cove...
# 3        1   So , it seems that those warm - weather lovin...

# %%
character_data_coref = json.load(open("/content/booknlp_output_FastCoref/story_2029/story_2029.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#                  Name Character ID  Mentions      Gender Possessives  \
# 0    Benny the Beaver            0        18  he/him/his          []
# 1  Sammy the Squirrel            1        18  he/him/his          []
#
#                                                Agent        Patient Modifiers
# 0        [(asked, 1), (noticed, 1), (remembered, 1)]  [(taught, 1)]        []
# 1  [(journeyed, 1), (know, 1), (clutching, 1), (r...  [(Benny, 10)]        []

# %%
df_quotes = pd.read_csv("/content/booknlp_output_FastCoref/story_0/story_0.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0           63         80             40           40          Sammy        1
# 1          100        127             95           95           Algy        0
# 2          151        164            148          148           Algy        0
# 3          184        205            175          175           Algy        0
# 4          213        234            210          210          Sammy        1
# 5          242        310            239          239           Algy        0
#
#                                                quote
# 0  “ Solve -1147 = -11*a - 1213 for ‘ a ’ . What ...
# 1  “ First , we need to get ‘ a ’ alone . To do t...
# 2  “ Now , we simplify both sides to make our wor...
# 3  “ Let ’s divide both sides by -11 now , so we ...
# 4  “ But wo n’t negative divided by negative give...
# 5  “ Great question , Sammy ! Yes , usually , neg...

# %%
df_train["story"][2488]
# Out:
# ' Once there was a little Eclectus Parrot named Eddie. Eddie lived in a small cage, much smaller than what his friend Polly the Macaw had. One day, while talking on the phone, Polly asked Eddie why he lived in such a tiny home.\n\n"My human says I don\'t need a big cage," Eddie replied. "She thinks I\'m happy here."\n\nPolly suggested they talk to Dr. Finch, their local bird expert, who would help Eddie understand the importance of having a spacious habitat. At Dr. Finch\'s office, they discovered fascinating facts about birds needing room to fly, hop, climb, and explore to stay healthy and content. She explained how bigger spaces allowed for toys, perches, and various activities that kept Eddie mentally stimulated.\n\nDr. Finch said, "Imagine being cooped up all day without any change in scenery! Birds require enriching environments to live happily."\n\nEddie finally realized how vital space was for him. He returned home and shared his newfound knowledge with his human companion. To
# ...

# %%
df_quotes = pd.read_csv("/content/booknlp_output_FastCoref/story_2488/story_2488.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end  \
# 0           74         86            106          108
# 1           95        103             89           92
# 2          252        273            230          231
#
#                 mention_phrase  char_id  \
# 0              Polly the Macaw        1
# 1  Eclectus Parrot named Eddie        0
# 2                    Dr. Finch        2
#
#                                                quote
# 0          My human says I do n't need a big cage ,
# 1                      She thinks I 'm happy here .
# 2   Imagine being cooped up all day without any c...

# %%
character_data_coref = json.load(open("/content/booknlp_output_FastCoref/story_2488/story_2488.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#               Name Character ID  Mentions           Gender  \
# 0            Eddie            0        39       he/him/his
# 1  Polly the Macaw            1         7  they/them/their
# 2        Dr. Finch            2         4  they/them/their
#
#                                          Possessives  \
# 0  [(friend, 5), (knowledge, 1), (companion, 1), ...
# 1                                       [(human, 1)]
# 2                                                 []
#
#                                                Agent  \
# 0  [(understand, 4), (replied, 1), (returned, 1),...
# 1                              [(had, 1), (need, 1)]
# 2                                   [(explained, 1)]
#
#                                  Patient     Modifiers
# 0  [(named, 7), (asked, 1), (shared, 1)]  [(happy, 1)]
# 1                                     []            []
# 2                                     []            []

# %%
df_quotes = pd.read_csv("/content/booknlp_output_FastCoref/story_15/story_15.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0          165        182            160          161      Fiona Fox        2
# 1          372        394            360          360         Oliver        0
#
#                                                quote
# 0  “ I smelled smoke earlier today ! Do you think...
# 1  “ We must spread awareness about protecting fo...

# %%
character_data_coref = json.load(open("/content/booknlp_output_FastCoref/story_15/story_15.book"))

# %%
df_train["story"][15]
# Out:
# " In the heart of a lush green forest, there lived many happy animals who called it home. There were fluffy bunnies hopping around, busy squirrels collecting nuts, and tall deer grazing on juicy leaves. High up above, colorful birds sang beautiful songs all day long. At the center of the forest was a wise old owl named Oliver, who loved observing his friends and fellow creatures.\n\nOne sunny morning, while chatting with Chippy the chipmunk, Oliver noticed something unusual. The air felt different – it was thicker and harder to breathe. They both wondered what had changed. That's when Fiona Fox appeared, coughing and sneezing uncontrollably. She shared her concern, “I smelled smoke earlier today! Do you think there might be a fire nearby?”\n\nWith worried expressions, they decided to investigate further. As they explored deeper into the woods, wisps of smoky clouds began appearing more frequently. Suddenly, they saw flames flickering menacingly close by. It became evident; a terrible
# ...

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#         Name Character ID  Mentions      Gender  \
# 0     Oliver            0         9  he/him/his
# 1  Fiona Fox            2         5  he/him/his
#
#                       Possessives  \
# 0  [(friends, 5), (creatures, 3)]
# 1                  [(concern, 1)]
#
#                                                Agent Patient Modifiers
# 0                                                 []      []        []
# 1  [(appeared, 1), (shared, 1), (smelled, 1), (th...      []        []

# %%
df_quotes = pd.read_csv("/content/booknlp_output_FastCoref/story_19/story_19.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end  \
# 0          117        120            122          124
# 1          138        143            126          126
# 2          151        178            148          148
# 3          186        197            183          183
# 4          210        247            207          207
# 5          347        371            332          342
# 6          381        401            378          378
# 7          406        453            402          402
#
#                                       mention_phrase  char_id  \
# 0                                      a curious boy        5
# 1                                              Timmy        0
# 2                                           Einstein        1
# 3                                              Timmy        0
# 4                                           Einstein        1
# 5  a strange - looking helicopter with two spinni...       22
# ...

# %%
character_data_coref = json.load(open("/content/booknlp_output_FastCoref/story_19/story_19.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#        Name Character ID  Mentions      Gender  \
# 0     Timmy            0        19  he/him/his
# 1    Helena            2         8     she/her
# 2  Einstein            1         7  he/him/his
#
#                                  Possessives  \
# 0                    [(bear, 3), (teddy, 1)]
# 1  [(friend, 1), (pressure, 1), (sister, 1)]
# 2                                         []
#
#                                                Agent Patient Modifiers
# 0                                                 []      []        []
# 1  [(sighed, 1), (suffered, 1), (seize, 1), (fall...      []        []
# 2  [(decided, 1), (admired, 1), (asked, 1), (repl...      []        []

# %%
df_train["story"][1965]
# Out:
# ' In Atomville, every creature was made up of tiny particles called atoms. Our friend Electra was an elephant who lived there, and she loved learning about how her own body worked! One day, she asked her best friend Proton, a curious rabbit, “Proton, I know my electrons carry a negative charge and move around in different levels. But why do they have more energy when they’re far from my core?”\n\nProton replied, “Well, Electra, imagine your house has several floors, and each floor needs some power to keep working. Your ground floor might only need enough electricity for a few lights, while the topmost floor may require much more power for all the gadgets inside. That extra power needed on higher floors can be compared to the increased energy in outer electron levels!”\n\nElectra nodded, understanding better now. She had always thought of herself as big, strong, and full of energy. However, hearing Proton compare her to a building helped her realize that being bigger didn’t necessaril
# ...

# %%
df_quotes = pd.read_csv("/content/booknlp_output_FastCoref/story_1965/story_1965.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end    mention_phrase  \
# 0           59         92             53           53            Proton
# 1          103        172             98          100  a curious rabbit
# 2          266        296            263          263           Neutron
# 3          361        384            349          350    another friend
#
#    char_id                                              quote
# 0        2  “ Proton , I know my electrons carry a negativ...
# 1       11  “ Well , Electra , imagine your house has seve...
# 2        3  “ But remember , even though these outer elect...
# 3       23  “ Even though we lost some energy , let ’s wor...

# %%
character_data_coref = json.load(open("/content/booknlp_output_FastCoref/story_1965/story_1965.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#       Name Character ID  Mentions           Gender  \
# 0  Electra            1        18          she/her
# 1   Proton            2         7  they/them/their
# 2  Neutron            3         3  they/them/their
#
#                                          Possessives        Agent Patient  \
# 0  [(friend, 3), (body, 1), (house, 1), (floor, 1...           []      []
# 1                        [(electrons, 1), (core, 1)]  [(know, 1)]      []
# 2                                      [(advice, 1)]  [(said, 1)]      []
#
#   Modifiers
# 0        []
# 1        []
# 2        []

# %%
df_quotes = pd.read_csv("/content/booknlp_output_FastCoref/story_2489/story_2489.quotes", delimiter="\t")
df_quotes.head(30)
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0          137        158            133          134  Little Aubrey        1
#
#                                                quote
# 0   Carson , I can not trust you anymore . It bre...

# %%
def get_counter_from_dependency_list(dependency_list):

    counter = Counter()

    for token in dependency_list:
        term = token["w"]
        tokenGlobalIndex=token["i"]
        counter[term] += 1
    return counter

# %%
character_data_coref = json.load(open("/content/booknlp_output/story_0.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#     Name Character ID  Mentions           Gender Possessives  \
# 0  Sammy            1         5       he/him/his          []
# 1   Algy            0         4  they/them/their          []
#
#                        Agent Patient    Modifiers
# 0               [(asked, 1)]      []           []
# 1  [(said, 1), (replied, 1)]      []  [(good, 1)]

# %%
character_data_coref = json.load(open("/content/booknlp_output_FastCoref/story_0/story_0.book"))

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                         'Mentions': count,
                       'Gender': referential_gender,
                       'Possessives': get_counter_from_dependency_list(possList).most_common(10),
                       'Agent': get_counter_from_dependency_list(agentList).most_common(10),
                       'Patient': get_counter_from_dependency_list(patientList).most_common(10),
                       'Modifiers': get_counter_from_dependency_list(modList).most_common(10)}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#     Name Character ID  Mentions      Gender  \
# 0   Algy            0        17  he/him/his
# 1  Sammy            1        16  he/him/his
#
#                              Possessives  \
# 0   [(step, 1), (success, 1), (eyes, 1)]
# 1  [(bench, 1), (success, 1), (eyes, 1)]
#
#                                                Agent Patient  \
# 0  [(loved, 1), (found, 1), (explained, 1), (adde...      []
# 1  [(loved, 1), (found, 1), (added, 1), (asked, 1...      []
#
#                  Modifiers
# 0  [(good, 1), (about, 1)]
# 1             [(about, 1)]

# %% [markdown]
# # Extraction

# %%
story = """
In a small town named Mathville, lived two best friends, Algy and Sammy. They loved solving puzzles and riddles together. One sunny day, they found a mysterious note on their favorite park bench. It read, “Solve -1147 = -11*a - 1213 for ‘a’. What is the answer?”

Algy, being good at numbers, decided to take up the challenge. He explained to Sammy, “First, we need to get ‘a’ alone. To do that, let’s add 1213 to both sides of the equation.” So, they added 1213 to -1147, making it 66.

Next, Algy said, “Now, we simplify both sides to make our work easier!” And voila! Both sides became 66. Excitedly, he shared his next step with Sammy: “Let’s divide both sides by -11 now, so we can finally see what ‘a’ equals!” A little confused, Sammy asked, “But won’t negative divided by negative give us positive? Why would we want to use minus here?”

With a smile, Algy replied, “Great question, Sammy! Yes, usually, negative divided by negative gives us positive. But when you divide a number by itself – no matter its sign – the result will always be 1 or, in this case, -1 since we have a negative number. That way, we maintain balance between the left and right side of the equation.” After dividing, they discovered that 'a' was equal to -6.

As they were about to celebrate their success, something unexpected happened. Suddenly, all the numbers around them started changing rapidly before their eyes. Trees turned into formulas, flowers transformed into equations, even birds chirped out integers. This bewildering spectacle made everyone realize how deeply intertwined math was with nature. Sometimes, unveiling answers leads us to surprising realizations. Though things didn't go back to normal immediately, they learned an essential lesson: Every discovery brings new wonders worth exploring.
"""

# %%
resolved_story = resolve_coreferences(story)
print(resolved_story)
# Out:
# ...
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# In a small town named Mathville, lived two best friends, Algy and Sammy. two best friends, Algy and Sammy loved solving puzzles and riddles together. One sunny day, two best friends, Algy and Sammy found a mysterious note on two best friends, Algy and Sammy's favorite park bench. a mysterious note read, “Solve -1147 = -11*a - 1213 for ‘a’. What is the answer?”
#
# Algy, being good at numbers, decided to take up the challenge. Algy explained to Sammy, “First, we need to get ‘a’ alone. To do that, let’s add 1213 to both sides of the equation.” So, two best friends, Algy and Sammy added 1213 to -1147, making it 66.
#
# ...

# %%
input_path = "inputStory.txt"
with open(input_path, "w", encoding="utf-8") as f:
    f.write(resolved_story)

bookId = "InputStory"
output_dir = f"booknlp_output_FastCoref/InputStory"

booknlp.process(input_path, output_dir, "InputStory")
# Out:
# --- spacy: 0.057 seconds ---
# --- entities: 0.900 seconds ---
# --- quotes: 0.000 seconds ---
# --- attribution: 0.129 seconds ---
# --- name coref: 0.000 seconds ---
# --- coref: 2.823 seconds ---
# --- TOTAL (excl. startup): 3.913 seconds ---, 455 words

# %%
# 1. Load the .book file (main annotations)
character_data_coref = json.load(open(f"{output_dir}/{bookId}.book"))

# %%
# 2. Load the .quotes file (quote speaker attributions)
quotes_path = f"{output_dir}/{bookId}.quotes"
quotes_df = pd.read_csv(quotes_path, sep='\t')

# %%
quotes_df
# Out:
#    quote_start  quote_end  mention_start  mention_end mention_phrase  char_id  \
# 0           63         80             40           40          Sammy        1
# 1          100        127             95           95           Algy        0
# 2          151        164            148          148           Algy        0
# 3          184        205            175          175           Algy        0
# 4          213        234            210          210          Sammy        1
# 5          242        310            239          239           Algy        0
#
#                                                quote
# 0  “ Solve -1147 = -11*a - 1213 for ‘ a ’ . What ...
# 1  “ First , we need to get ‘ a ’ alone . To do t...
# 2  “ Now , we simplify both sides to make our wor...
# 3  “ Let ’s divide both sides by -11 now , so we ...
# 4  “ But wo n’t negative divided by negative give...
# 5  “ Great question , Sammy ! Yes , usually , neg...

# %%
import re

def segment_story(story):
    segments = []
    parts = re.split(r'(“[^”]+”)', story)  # splits on dialogues in quotes
    for part in parts:
        part = part.strip()
        if not part:
            continue
        if part.startswith("“") and part.endswith("”"):
            segments.append(f"X: {part[1:-1]}")  # dialogue without quotes
        else:
            segments.append(f"Narrator: {part}")
    return segments

# Get segmented story
segmented = segment_story(story)

# Print the results
for line in segmented:
    print(line)
# Out:
# Narrator: In a small town named Mathville, lived two best friends, Algy and Sammy. They loved solving puzzles and riddles together. One sunny day, they found a mysterious note on their favorite park bench. It read,
# X: Solve -1147 = -11*a - 1213 for ‘a’. What is the answer?
# Narrator: Algy, being good at numbers, decided to take up the challenge. He explained to Sammy,
# X: First, we need to get ‘a’ alone. To do that, let’s add 1213 to both sides of the equation.
# Narrator: So, they added 1213 to -1147, making it 66.
#
# Next, Algy said,
# X: Now, we simplify both sides to make our work easier!
# Narrator: And voila! Both sides became 66. Excitedly, he shared his next step with Sammy:
# X: Let’s divide both sides by -11 now, so we can finally see what ‘a’ equals!
# Narrator: A little confused, Sammy asked,
# X: But won’t negative divided by negative give us positive? Why would we want to use minus here?
# Narrator: With a smile, Algy replied,
# ...

# %%
from difflib import get_close_matches

# Copy the segmented list so we can edit it
mapped_segments = segmented.copy()
quote_texts = quotes_df['quote'].str.replace('“|”', '').str.strip().tolist()
speakers = quotes_df['mention_phrase'].tolist()

# Iterate through segments, and replace "X" with actual speaker if matched
for i, segment in enumerate(mapped_segments):
    if segment.startswith("X:"):
        # Extract the dialogue part
        dialogue = segment[3:].strip()

        # Try to find the closest matching quote from quotes_df
        match = get_close_matches(dialogue, quote_texts, n=1, cutoff=0.6)

        if match:
            match_text = match[0]
            idx = quote_texts.index(match_text)
            speaker = speakers[idx]
            mapped_segments[i] = f"{speaker}: {dialogue}"

# Print or use the final list
for line in mapped_segments:
    print("---",line)
# Out:
# --- Narrator: In a small town named Mathville, lived two best friends, Algy and Sammy. They loved solving puzzles and riddles together. One sunny day, they found a mysterious note on their favorite park bench. It read,
# --- Sammy: Solve -1147 = -11*a - 1213 for ‘a’. What is the answer?
# --- Narrator: Algy, being good at numbers, decided to take up the challenge. He explained to Sammy,
# --- Algy: First, we need to get ‘a’ alone. To do that, let’s add 1213 to both sides of the equation.
# --- Narrator: So, they added 1213 to -1147, making it 66.
#
# Next, Algy said,
# --- Algy: Now, we simplify both sides to make our work easier!
# --- Narrator: And voila! Both sides became 66. Excitedly, he shared his next step with Sammy:
# --- Algy: Let’s divide both sides by -11 now, so we can finally see what ‘a’ equals!
# --- Narrator: A little confused, Sammy asked,
# --- Sammy: But won’t negative divided by negative give us positive? Why would we want to use minus here?
# ...

# %%
import csv

# Clean and prepare rows
rows = []
for line in mapped_segments:
    if line.startswith("---"):
        line = line[3:].strip()  # remove leading ---
    if ": " in line:
        speaker, text = line.split(": ", 1)
        rows.append({"speaker": speaker.strip(), "text": text.strip()})

# Write to CSV
csv_filename = "dialogue_output.csv"
with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=["speaker", "text"])
    writer.writeheader()
    writer.writerows(rows)

print(f"CSV file '{csv_filename}' created with all narration and dialogue intact.")
# Out:
# CSV file 'dialogue_output.csv' created with all narration and dialogue intact.

# %%
df_list = []
for character in character_data_coref["characters"]:

    agentList = character["agent"]
    patientList = character["patient"]
    possList = character["poss"]
    modList = character["mod"]
    character_id = character["id"]
    count = character["count"]
    referential_gender_distribution = referential_gender_prediction="unknown"

    if character["g"] is not None and character["g"] != "unknown":
        referential_gender_distribution=character["g"]["inference"]
        referential_gender=character["g"]["argmax"]

    mentions=character["mentions"]
    proper_mentions=mentions["proper"]
    max_proper_mention=""

    # just print out information about named characters
    if len(mentions["proper"]) > 0:
        max_proper_mention=mentions["proper"][0]["n"]

        df_list.append( {'Name':max_proper_mention , 'Character ID': character_id,
                       'Gender': referential_gender}
        )
df = pd.DataFrame(df_list)
df['Character ID'] = df['Character ID'].astype(str)
df
# Out:
#     Name Character ID      Gender
# 0   Algy            0  he/him/his
# 1  Sammy            1  he/him/his

# %%
def pronoun_to_gender(pronoun_str):
    pronoun_str = pronoun_str.lower()  # normalize case
    if "he" in pronoun_str:
        return "male"
    elif "she" in pronoun_str:
        return "female"
    else:
        return "unknown"

# Assuming df has 'Name' and 'Gender' columns
character_gender_dict = {
    row["Name"]: pronoun_to_gender(row["Gender"])
    for _, row in df.iterrows()
}

print(character_gender_dict)

character_gender_dict = pd.DataFrame(list(character_gender_dict.items()), columns=['Name', 'Gender'])
character_gender_dict.to_csv("GenderAssignment.csv")
# Out:
# {'Algy': 'male', 'Sammy': 'male'}
