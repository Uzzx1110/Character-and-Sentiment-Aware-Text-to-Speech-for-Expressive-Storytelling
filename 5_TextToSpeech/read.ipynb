# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Character-and-Sentiment-Aware-Text-to-Speech-for-Expressive-Storytelling\TextToSpeech\quotes_with_emotions.csv")
df.head(30)
# Out:
#      speaker                                               text emotions
# 0   Narrator  In a small town named Mathville, lived two bes...  Neutral
# 1      Sammy  Solve -1147 = -11*a - 1213 for ‘a’. What is th...      joy
# 2   Narrator  Algy, being good at numbers, decided to take u...  Neutral
# 3       Algy  First, we need to get ‘a’ alone. To do that, l...  sadness
# 4   Narrator  So, they added 1213 to -1147, making it 66.\n\...  Neutral
# 5       Algy  Now, we simplify both sides to make our work e...    anger
# 6   Narrator  And voila! Both sides became 66. Excitedly, he...  Neutral
# 7       Algy  Let’s divide both sides by -11 now, so we can ...      joy
# 8   Narrator                    A little confused, Sammy asked,  Neutral
# 9      Sammy  But won’t negative divided by negative give us...      joy
# 10  Narrator                        With a smile, Algy replied,  Neutral
# 11      Algy  Great question, Sammy! Yes, usually, negative ...      joy
# ...
